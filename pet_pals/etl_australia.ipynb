# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
import os, zipfile
import shutil
import glob

from pymongo import MongoClient
import time

# %% [markdown]
# ## Extract data

# %%
# Running this cell will unzip the data files in the Resources folder.
extension = ".zip"
extracted_dir_name = "."

# Get the current working directory.
# Need to be in the root directory of this project for this to work.
cwd_dir_name = os.getcwd()
print(f"The current working directory is {cwd_dir_name}.")

os.chdir("Resources") # change directory from working dir to dir with the zip file(s) .
# This should be the "Resources" folder.
dir_name = os.getcwd()
print(f"You are now in the following directory: {dir_name}.")

for item in os.listdir(dir_name): # loop through the items in the directory.
    if item.endswith(extension): # check for ".zip" extension"
        try:
            file_name = os.path.abspath(item) # get full path of files
            zip_ref = zipfile.ZipFile(file_name) # create zipfile object
            unzipped_directory = os.path.join(extracted_dir_name) # reference to the directory where the zip files will be extracted.
            zip_ref.extractall(unzipped_directory) # extract file to dir
            zip_ref.close() # close file
            print(f"Successfully unzipped {item} into the following folder:{dir_name}.")
        except:
            print(f"Error trying to unzip data file(s).")
            print(f"Make sure that the files are closed and you have the correct file/folder permissions.")
            
# Go up one directory into the project root directory.
os.chdir(os.path.normpath(os.getcwd() + os.sep + os.pardir))
print(os.path.normpath(os.getcwd() + os.sep + os.pardir))
# Out:
# The current working directory is C:\Users\phili\Desktop\flask-heroku-deploy\pet_pals.
# You are now in the following directory: C:\Users\phili\Desktop\flask-heroku-deploy\pet_pals\Resources.
# Successfully unzipped fires-from-space-australia-and-new-zeland.zip into the following folder:C:\Users\phili\Desktop\flask-heroku-deploy\pet_pals\Resources.
# C:\Users\phili\Desktop\flask-heroku-deploy

# %% [markdown]
# ## Import csv files and read into pandas dataframes

# %%
# Path to the csv files.
path_to_csvs = os.path.join(".", "Resources")
all_files = glob.glob(os.path.join(path_to_csvs, "*.csv"))

df_from_each_file = []

for f in all_files:
    filename = os.path.basename(f)
    df = pd.read_csv(f, encoding ="ISO-8859-1")
    df_from_each_file.append(df)

# Concantenated dataframe
concatenated_df = pd.concat(df_from_each_file, ignore_index=True)
concatenated_df
# Out:
#            acq_date  acq_time  bright_t31  bright_ti4  bright_ti5  brightness  \
# 0        2019-08-01        56       297.3         NaN         NaN       313.0
# 1        2019-08-01        56       297.3         NaN         NaN       319.3
# 2        2019-08-01        57       298.7         NaN         NaN       311.6
# 3        2019-08-01        57       296.1         NaN         NaN       310.1
# 4        2019-08-01        57       298.8         NaN         NaN       310.3
# ...             ...       ...         ...         ...         ...         ...
# 1360634  2020-01-11      1630         NaN       306.9       288.6         NaN
# 1360635  2020-01-11      1630         NaN       299.0       287.4         NaN
# 1360636  2020-01-11      1630         NaN       309.7       291.7         NaN
# 1360637  2020-01-11      1806         NaN       300.2       290.2         NaN
# 1360638  2020-01-11      1806         NaN       300.3       290.0         NaN
#
#         confidence daynight   frp instrument  latitude  longitude satellite  \
# 0               48        D   6.6      MODIS -11.80700  142.05830     Terra
# 1               71        D  11.3      MODIS -11.79240  142.08500     Terra
# 2               42        D  23.1      MODIS -12.83980  132.87440     Terra
# 3               33        D   6.5      MODIS -14.43060  143.30350     Terra
# 4               36        D  27.6      MODIS -12.49530  131.48970     Terra
# ...            ...      ...   ...        ...       ...        ...       ...
# 1360634          n        N   0.8      VIIRS -32.66628  122.15253         N
# 1360635          n        N   0.7      VIIRS -32.58616  123.39582         N
# 1360636          n        N   1.0      VIIRS -33.37853  115.94735         N
# 1360637          n        N   1.1      VIIRS -33.21827  115.75078         N
# 1360638          n        N   0.6      VIIRS -33.22012  115.75043         N
#
#          scan  track  type version
# 0        1.00   1.00   0.0     6.3
# 1        1.00   1.00   0.0     6.3
# 2        3.10   1.70   0.0     6.3
# 3        1.10   1.10   0.0     6.3
# 4        4.00   1.90   0.0     6.3
# ...       ...    ...   ...     ...
# 1360634  0.39   0.44   NaN  1.0NRT
# 1360635  0.51   0.41   NaN  1.0NRT
# 1360636  0.40   0.60   NaN  1.0NRT
# 1360637  0.49   0.65   NaN  1.0NRT
# 1360638  0.49   0.65   NaN  1.0NRT
#
# [1360639 rows x 17 columns]

# %%
# Remove unneccessary columns
del concatenated_df["bright_t31"]
del concatenated_df["bright_ti4"]
del concatenated_df["bright_ti5"]
del concatenated_df["confidence"]
del concatenated_df["scan"]
del concatenated_df["track"]
del concatenated_df["version"]
del concatenated_df["type"]

# %%
concatenated_df
# Out:
#            acq_date  acq_time  brightness daynight   frp instrument  latitude  \
# 0        2019-08-01        56       313.0        D   6.6      MODIS -11.80700
# 1        2019-08-01        56       319.3        D  11.3      MODIS -11.79240
# 2        2019-08-01        57       311.6        D  23.1      MODIS -12.83980
# 3        2019-08-01        57       310.1        D   6.5      MODIS -14.43060
# 4        2019-08-01        57       310.3        D  27.6      MODIS -12.49530
# ...             ...       ...         ...      ...   ...        ...       ...
# 1360634  2020-01-11      1630         NaN        N   0.8      VIIRS -32.66628
# 1360635  2020-01-11      1630         NaN        N   0.7      VIIRS -32.58616
# 1360636  2020-01-11      1630         NaN        N   1.0      VIIRS -33.37853
# 1360637  2020-01-11      1806         NaN        N   1.1      VIIRS -33.21827
# 1360638  2020-01-11      1806         NaN        N   0.6      VIIRS -33.22012
#
#          longitude satellite
# 0        142.05830     Terra
# 1        142.08500     Terra
# 2        132.87440     Terra
# 3        143.30350     Terra
# 4        131.48970     Terra
# ...            ...       ...
# 1360634  122.15253         N
# 1360635  123.39582         N
# 1360636  115.94735         N
# 1360637  115.75078         N
# 1360638  115.75043         N
#
# [1360639 rows x 9 columns]

# %%
# Verify counts
concatenated_df.count()
# Out:
# acq_date      1360639
# acq_time      1360639
# brightness     219604
# daynight      1175861
# frp           1360639
# instrument    1360639
# latitude      1360639
# longitude     1360639
# satellite     1360639
# dtype: int64

# %%
# Drop nas/null values
concatenated_df = concatenated_df.dropna(how="any")

concatenated_df.count()
# Out:
# acq_date      219604
# acq_time      219604
# brightness    219604
# daynight      219604
# frp           219604
# instrument    219604
# latitude      219604
# longitude     219604
# satellite     219604
# dtype: int64

# %%
# Check data types
concatenated_df.dtypes
# Out:
# acq_date       object
# acq_time        int64
# brightness    float64
# daynight       object
# frp           float64
# instrument     object
# latitude      float64
# longitude     float64
# satellite      object
# dtype: object

# %%
# Convert dataframe to dictionary.
fires_from_space = concatenated_df.to_dict('range')

fires_from_space
# Out:
# [{'acq_date': '2019-08-01',
#   'acq_time': 56,
#   'brightness': 313.0,
#   'daynight': 'D',
#   'frp': 6.6,
#   'instrument': 'MODIS',
#   'latitude': -11.807,
#   'longitude': 142.0583,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 56,
#   'brightness': 319.3,
#   'daynight': 'D',
#   'frp': 11.3,
#   'instrument': 'MODIS',
#   'latitude': -11.7924,
#   'longitude': 142.085,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 311.6,
#   'daynight': 'D',
#   'frp': 23.1,
#   'instrument': 'MODIS',
#   'latitude': -12.8398,
#   'longitude': 132.8744,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 310.1,
#   'daynight': 'D',
#   'frp': 6.5,
#   'instrument': 'MODIS',
#   'latitude': -14.4306,
#   'longitude': 143.3035,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 310.3,
#   'daynight': 'D',
#   'frp': 27.6,
#   'instrument': 'MODIS',
#   'latitude': -12.4953,
#   'longitude': 131.4897,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.8,
#   'daynight': 'D',
#   'frp': 9.3,
#   'instrument': 'MODIS',
#   'latitude': -12.6191,
#   'longitude': 142.1998,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 305.4,
#   'daynight': 'D',
#   'frp': 5.9,
#   'instrument': 'MODIS',
#   'latitude': -14.3655,
#   'longitude': 143.5682,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 322.9,
#   'daynight': 'D',
#   'frp': 20.4,
#   'instrument': 'MODIS',
#   'latitude': -14.3195,
#   'longitude': 143.5198,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 317.2,
#   'daynight': 'D',
#   'frp': 9.9,
#   'instrument': 'MODIS',
#   'latitude': -13.1654,
#   'longitude': 141.9715,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 311.5,
#   'daynight': 'D',
#   'frp': 27.3,
#   'instrument': 'MODIS',
#   'latitude': -11.5473,
#   'longitude': 132.6796,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 312.2,
#   'daynight': 'D',
#   'frp': 31.4,
#   'instrument': 'MODIS',
#   'latitude': -11.5417,
#   'longitude': 132.649,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 316.0,
#   'daynight': 'D',
#   'frp': 52.7,
#   'instrument': 'MODIS',
#   'latitude': -11.5471,
#   'longitude': 132.6538,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 335.2,
#   'daynight': 'D',
#   'frp': 30.1,
#   'instrument': 'MODIS',
#   'latitude': -12.7626,
#   'longitude': 142.1759,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 311.7,
#   'daynight': 'D',
#   'frp': 20.6,
#   'instrument': 'MODIS',
#   'latitude': -12.705,
#   'longitude': 133.907,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 315.9,
#   'daynight': 'D',
#   'frp': 29.5,
#   'instrument': 'MODIS',
#   'latitude': -13.1092,
#   'longitude': 134.1848,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 316.0,
#   'daynight': 'D',
#   'frp': 7.8,
#   'instrument': 'MODIS',
#   'latitude': -14.0539,
#   'longitude': 142.3327,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 310.9,
#   'daynight': 'D',
#   'frp': 17.6,
#   'instrument': 'MODIS',
#   'latitude': -12.6996,
#   'longitude': 133.9138,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.8,
#   'daynight': 'D',
#   'frp': 22.8,
#   'instrument': 'MODIS',
#   'latitude': -12.7499,
#   'longitude': 134.5251,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 313.9,
#   'daynight': 'D',
#   'frp': 23.0,
#   'instrument': 'MODIS',
#   'latitude': -12.7141,
#   'longitude': 134.3991,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.0,
#   'daynight': 'D',
#   'frp': 21.2,
#   'instrument': 'MODIS',
#   'latitude': -12.7061,
#   'longitude': 134.4077,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 315.7,
#   'daynight': 'D',
#   'frp': 6.7,
#   'instrument': 'MODIS',
#   'latitude': -13.8656,
#   'longitude': 141.9771,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 324.9,
#   'daynight': 'D',
#   'frp': 57.7,
#   'instrument': 'MODIS',
#   'latitude': -12.6491,
#   'longitude': 134.3953,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 311.3,
#   'daynight': 'D',
#   'frp': 17.2,
#   'instrument': 'MODIS',
#   'latitude': -13.1015,
#   'longitude': 134.1926,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 322.4,
#   'daynight': 'D',
#   'frp': 13.7,
#   'instrument': 'MODIS',
#   'latitude': -12.6703,
#   'longitude': 142.1102,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 318.6,
#   'daynight': 'D',
#   'frp': 11.6,
#   'instrument': 'MODIS',
#   'latitude': -13.3042,
#   'longitude': 142.04,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 325.3,
#   'daynight': 'D',
#   'frp': 16.2,
#   'instrument': 'MODIS',
#   'latitude': -13.2236,
#   'longitude': 141.9914,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 306.5,
#   'daynight': 'D',
#   'frp': 5.4,
#   'instrument': 'MODIS',
#   'latitude': -13.2821,
#   'longitude': 142.4617,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 325.5,
#   'daynight': 'D',
#   'frp': 17.6,
#   'instrument': 'MODIS',
#   'latitude': -13.2159,
#   'longitude': 142.002,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 310.0,
#   'daynight': 'D',
#   'frp': 4.3,
#   'instrument': 'MODIS',
#   'latitude': -13.2537,
#   'longitude': 142.5242,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 320.2,
#   'daynight': 'D',
#   'frp': 13.0,
#   'instrument': 'MODIS',
#   'latitude': -12.4513,
#   'longitude': 141.8071,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 328.6,
#   'daynight': 'D',
#   'frp': 21.8,
#   'instrument': 'MODIS',
#   'latitude': -12.4527,
#   'longitude': 141.8162,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 317.6,
#   'daynight': 'D',
#   'frp': 8.8,
#   'instrument': 'MODIS',
#   'latitude': -12.544,
#   'longitude': 142.4455,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 317.0,
#   'daynight': 'D',
#   'frp': 8.2,
#   'instrument': 'MODIS',
#   'latitude': -12.463,
#   'longitude': 141.8241,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 336.5,
#   'daynight': 'D',
#   'frp': 31.5,
#   'instrument': 'MODIS',
#   'latitude': -12.5567,
#   'longitude': 141.8979,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 318.2,
#   'daynight': 'D',
#   'frp': 8.9,
#   'instrument': 'MODIS',
#   'latitude': -12.5581,
#   'longitude': 141.9071,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 316.7,
#   'daynight': 'D',
#   'frp': 49.9,
#   'instrument': 'MODIS',
#   'latitude': -13.2313,
#   'longitude': 131.9106,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 319.1,
#   'daynight': 'D',
#   'frp': 61.1,
#   'instrument': 'MODIS',
#   'latitude': -13.2394,
#   'longitude': 131.9032,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 315.3,
#   'daynight': 'D',
#   'frp': 37.0,
#   'instrument': 'MODIS',
#   'latitude': -13.2993,
#   'longitude': 131.9598,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.2,
#   'daynight': 'D',
#   'frp': 31.6,
#   'instrument': 'MODIS',
#   'latitude': -13.3151,
#   'longitude': 131.9569,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 319.7,
#   'daynight': 'D',
#   'frp': 15.0,
#   'instrument': 'MODIS',
#   'latitude': -15.3551,
#   'longitude': 142.3028,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 329.2,
#   'daynight': 'D',
#   'frp': 25.0,
#   'instrument': 'MODIS',
#   'latitude': -15.3658,
#   'longitude': 142.3113,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.3,
#   'daynight': 'D',
#   'frp': 15.3,
#   'instrument': 'MODIS',
#   'latitude': -14.2726,
#   'longitude': 135.0443,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 314.3,
#   'daynight': 'D',
#   'frp': 10.7,
#   'instrument': 'MODIS',
#   'latitude': -15.4778,
#   'longitude': 142.5924,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 321.8,
#   'daynight': 'D',
#   'frp': 35.7,
#   'instrument': 'MODIS',
#   'latitude': -14.3048,
#   'longitude': 134.9182,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 316.1,
#   'daynight': 'D',
#   'frp': 20.5,
#   'instrument': 'MODIS',
#   'latitude': -14.308,
#   'longitude': 134.9367,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 319.2,
#   'daynight': 'D',
#   'frp': 10.1,
#   'instrument': 'MODIS',
#   'latitude': -12.7613,
#   'longitude': 142.1666,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 324.0,
#   'daynight': 'D',
#   'frp': 80.1,
#   'instrument': 'MODIS',
#   'latitude': -12.8447,
#   'longitude': 132.9017,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 57,
#   'brightness': 312.6,
#   'daynight': 'D',
#   'frp': 24.7,
#   'instrument': 'MODIS',
#   'latitude': -12.8782,
#   'longitude': 132.9177,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 312.6,
#   'daynight': 'D',
#   'frp': 30.2,
#   'instrument': 'MODIS',
#   'latitude': -15.0081,
#   'longitude': 131.7665,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 377.6,
#   'daynight': 'D',
#   'frp': 208.1,
#   'instrument': 'MODIS',
#   'latitude': -15.7637,
#   'longitude': 137.0728,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 319.5,
#   'daynight': 'D',
#   'frp': 14.5,
#   'instrument': 'MODIS',
#   'latitude': -15.7678,
#   'longitude': 137.0335,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 345.8,
#   'daynight': 'D',
#   'frp': 71.3,
#   'instrument': 'MODIS',
#   'latitude': -15.7699,
#   'longitude': 137.046,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 321.4,
#   'daynight': 'D',
#   'frp': 17.1,
#   'instrument': 'MODIS',
#   'latitude': -15.7863,
#   'longitude': 137.0816,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 313.6,
#   'daynight': 'D',
#   'frp': 46.2,
#   'instrument': 'MODIS',
#   'latitude': -14.651,
#   'longitude': 130.5884,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 312.4,
#   'daynight': 'D',
#   'frp': 40.0,
#   'instrument': 'MODIS',
#   'latitude': -14.6536,
#   'longitude': 130.5824,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 312.6,
#   'daynight': 'D',
#   'frp': 42.0,
#   'instrument': 'MODIS',
#   'latitude': -14.6614,
#   'longitude': 130.6219,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 311.9,
#   'daynight': 'D',
#   'frp': 39.4,
#   'instrument': 'MODIS',
#   'latitude': -14.727,
#   'longitude': 130.6886,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 318.3,
#   'daynight': 'D',
#   'frp': 54.8,
#   'instrument': 'MODIS',
#   'latitude': -14.9422,
#   'longitude': 131.8184,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 336.7,
#   'daynight': 'D',
#   'frp': 44.5,
#   'instrument': 'MODIS',
#   'latitude': -15.7616,
#   'longitude': 137.0603,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 315.0,
#   'daynight': 'D',
#   'frp': 46.2,
#   'instrument': 'MODIS',
#   'latitude': -15.1411,
#   'longitude': 131.1486,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 313.2,
#   'daynight': 'D',
#   'frp': 37.3,
#   'instrument': 'MODIS',
#   'latitude': -15.1317,
#   'longitude': 131.1449,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 367.6,
#   'daynight': 'D',
#   'frp': 162.2,
#   'instrument': 'MODIS',
#   'latitude': -16.144000000000002,
#   'longitude': 136.7135,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 312.2,
#   'daynight': 'D',
#   'frp': 31.4,
#   'instrument': 'MODIS',
#   'latitude': -15.1544,
#   'longitude': 131.1757,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 349.3,
#   'daynight': 'D',
#   'frp': 84.5,
#   'instrument': 'MODIS',
#   'latitude': -16.1479,
#   'longitude': 136.6726,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 345.1,
#   'daynight': 'D',
#   'frp': 69.9,
#   'instrument': 'MODIS',
#   'latitude': -16.1501,
#   'longitude': 136.6857,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 339.3,
#   'daynight': 'D',
#   'frp': 52.0,
#   'instrument': 'MODIS',
#   'latitude': -16.1545,
#   'longitude': 136.7117,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 328.5,
#   'daynight': 'D',
#   'frp': 30.8,
#   'instrument': 'MODIS',
#   'latitude': -16.1646,
#   'longitude': 136.6428,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 310.8,
#   'daynight': 'D',
#   'frp': 33.9,
#   'instrument': 'MODIS',
#   'latitude': -15.1018,
#   'longitude': 130.5473,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 309.7,
#   'daynight': 'D',
#   'frp': 27.9,
#   'instrument': 'MODIS',
#   'latitude': -15.1089,
#   'longitude': 130.5845,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 315.3,
#   'daynight': 'D',
#   'frp': 76.1,
#   'instrument': 'MODIS',
#   'latitude': -15.1657,
#   'longitude': 129.9294,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 313.4,
#   'daynight': 'D',
#   'frp': 63.3,
#   'instrument': 'MODIS',
#   'latitude': -15.1644,
#   'longitude': 129.9221,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 318.5,
#   'daynight': 'D',
#   'frp': 68.1,
#   'instrument': 'MODIS',
#   'latitude': -15.5022,
#   'longitude': 130.6313,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 314.4,
#   'daynight': 'D',
#   'frp': 48.5,
#   'instrument': 'MODIS',
#   'latitude': -15.4825,
#   'longitude': 130.4364,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 314.7,
#   'daynight': 'D',
#   'frp': 44.7,
#   'instrument': 'MODIS',
#   'latitude': -15.4967,
#   'longitude': 130.6638,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 317.6,
#   'daynight': 'D',
#   'frp': 65.5,
#   'instrument': 'MODIS',
#   'latitude': -15.5059,
#   'longitude': 130.623,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 312.4,
#   'daynight': 'D',
#   'frp': 39.6,
#   'instrument': 'MODIS',
#   'latitude': -15.485,
#   'longitude': 130.4285,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 58,
#   'brightness': 315.0,
#   'daynight': 'D',
#   'frp': 49.2,
#   'instrument': 'MODIS',
#   'latitude': -14.0156,
#   'longitude': 131.5979,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 59,
#   'brightness': 311.5,
#   'daynight': 'D',
#   'frp': 5.9,
#   'instrument': 'MODIS',
#   'latitude': -20.7333,
#   'longitude': 139.47899999999998,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 101,
#   'brightness': 308.1,
#   'daynight': 'D',
#   'frp': 31.0,
#   'instrument': 'MODIS',
#   'latitude': -28.0219,
#   'longitude': 148.1972,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 102,
#   'brightness': 303.7,
#   'daynight': 'D',
#   'frp': 19.2,
#   'instrument': 'MODIS',
#   'latitude': -32.2111,
#   'longitude': 146.7604,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 102,
#   'brightness': 309.2,
#   'daynight': 'D',
#   'frp': 38.7,
#   'instrument': 'MODIS',
#   'latitude': -32.2088,
#   'longitude': 146.7257,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 323.4,
#   'daynight': 'D',
#   'frp': 98.1,
#   'instrument': 'MODIS',
#   'latitude': -14.6671,
#   'longitude': 126.7783,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 324.4,
#   'daynight': 'D',
#   'frp': 114.8,
#   'instrument': 'MODIS',
#   'latitude': -14.668,
#   'longitude': 126.7715,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 324.1,
#   'daynight': 'D',
#   'frp': 114.9,
#   'instrument': 'MODIS',
#   'latitude': -14.6721,
#   'longitude': 126.8129,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 339.8,
#   'daynight': 'D',
#   'frp': 287.9,
#   'instrument': 'MODIS',
#   'latitude': -14.6855,
#   'longitude': 126.7699,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 324.6,
#   'daynight': 'D',
#   'frp': 113.4,
#   'instrument': 'MODIS',
#   'latitude': -14.6896,
#   'longitude': 126.8108,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 315.2,
#   'daynight': 'D',
#   'frp': 45.5,
#   'instrument': 'MODIS',
#   'latitude': -14.7213,
#   'longitude': 126.7612,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 315.1,
#   'daynight': 'D',
#   'frp': 45.9,
#   'instrument': 'MODIS',
#   'latitude': -16.0896,
#   'longitude': 125.9278,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 312.9,
#   'daynight': 'D',
#   'frp': 33.1,
#   'instrument': 'MODIS',
#   'latitude': -16.0778,
#   'longitude': 125.9238,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 312.8,
#   'daynight': 'D',
#   'frp': 37.5,
#   'instrument': 'MODIS',
#   'latitude': -16.1692,
#   'longitude': 125.9902,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 236,
#   'brightness': 344.9,
#   'daynight': 'D',
#   'frp': 362.5,
#   'instrument': 'MODIS',
#   'latitude': -14.6846,
#   'longitude': 126.7765,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 240,
#   'brightness': 305.6,
#   'daynight': 'D',
#   'frp': 7.4,
#   'instrument': 'MODIS',
#   'latitude': -29.6694,
#   'longitude': 116.5634,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 240,
#   'brightness': 304.2,
#   'daynight': 'D',
#   'frp': 5.3,
#   'instrument': 'MODIS',
#   'latitude': -29.429000000000002,
#   'longitude': 115.0197,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 305.9,
#   'daynight': 'D',
#   'frp': 14.4,
#   'instrument': 'MODIS',
#   'latitude': -34.082,
#   'longitude': 116.7357,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 301.7,
#   'daynight': 'D',
#   'frp': 5.6,
#   'instrument': 'MODIS',
#   'latitude': -31.2771,
#   'longitude': 115.845,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 301.4,
#   'daynight': 'D',
#   'frp': 8.5,
#   'instrument': 'MODIS',
#   'latitude': -32.4999,
#   'longitude': 116.0805,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 302.3,
#   'daynight': 'D',
#   'frp': 9.7,
#   'instrument': 'MODIS',
#   'latitude': -32.8685,
#   'longitude': 116.5515,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 304.6,
#   'daynight': 'D',
#   'frp': 35.1,
#   'instrument': 'MODIS',
#   'latitude': -33.7142,
#   'longitude': 122.2123,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 300.2,
#   'daynight': 'D',
#   'frp': 9.7,
#   'instrument': 'MODIS',
#   'latitude': -33.6942,
#   'longitude': 117.6054,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 303.0,
#   'daynight': 'D',
#   'frp': 11.8,
#   'instrument': 'MODIS',
#   'latitude': -33.6976,
#   'longitude': 117.2918,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 304.5,
#   'daynight': 'D',
#   'frp': 11.8,
#   'instrument': 'MODIS',
#   'latitude': -34.0838,
#   'longitude': 116.7459,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 300.9,
#   'daynight': 'D',
#   'frp': 7.1,
#   'instrument': 'MODIS',
#   'latitude': -33.9346,
#   'longitude': 115.166,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 356.7,
#   'daynight': 'D',
#   'frp': 138.3,
#   'instrument': 'MODIS',
#   'latitude': -34.1447,
#   'longitude': 116.3721,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 401.5,
#   'daynight': 'D',
#   'frp': 461.8,
#   'instrument': 'MODIS',
#   'latitude': -34.1465,
#   'longitude': 116.3881,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 402.3,
#   'daynight': 'D',
#   'frp': 470.3,
#   'instrument': 'MODIS',
#   'latitude': -34.1486,
#   'longitude': 116.3819,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 337.8,
#   'daynight': 'D',
#   'frp': 72.4,
#   'instrument': 'MODIS',
#   'latitude': -34.1502,
#   'longitude': 116.3977,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 300.1,
#   'daynight': 'D',
#   'frp': 11.8,
#   'instrument': 'MODIS',
#   'latitude': -34.5699,
#   'longitude': 118.5261,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 241,
#   'brightness': 306.5,
#   'daynight': 'D',
#   'frp': 22.0,
#   'instrument': 'MODIS',
#   'latitude': -34.5719,
#   'longitude': 118.5483,
#   'satellite': 'Terra'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 340,
#   'brightness': 305.6,
#   'daynight': 'D',
#   'frp': 9.6,
#   'instrument': 'MODIS',
#   'latitude': -33.5541,
#   'longitude': 147.8052,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 340,
#   'brightness': 310.5,
#   'daynight': 'D',
#   'frp': 9.9,
#   'instrument': 'MODIS',
#   'latitude': -34.468,
#   'longitude': 150.8807,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 327.0,
#   'daynight': 'D',
#   'frp': 26.3,
#   'instrument': 'MODIS',
#   'latitude': -31.7148,
#   'longitude': 151.0734,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 310.5,
#   'daynight': 'D',
#   'frp': 8.3,
#   'instrument': 'MODIS',
#   'latitude': -31.7162,
#   'longitude': 151.0615,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 323.2,
#   'daynight': 'D',
#   'frp': 29.5,
#   'instrument': 'MODIS',
#   'latitude': -31.7932,
#   'longitude': 148.5045,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 333.6,
#   'daynight': 'D',
#   'frp': 53.4,
#   'instrument': 'MODIS',
#   'latitude': -31.7949,
#   'longitude': 148.4881,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 308.4,
#   'daynight': 'D',
#   'frp': 6.0,
#   'instrument': 'MODIS',
#   'latitude': -31.3758,
#   'longitude': 150.696,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 320.7,
#   'daynight': 'D',
#   'frp': 18.3,
#   'instrument': 'MODIS',
#   'latitude': -31.3773,
#   'longitude': 150.6837,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 311.9,
#   'daynight': 'D',
#   'frp': 10.4,
#   'instrument': 'MODIS',
#   'latitude': -31.3949,
#   'longitude': 149.6613,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 308.5,
#   'daynight': 'D',
#   'frp': 5.1,
#   'instrument': 'MODIS',
#   'latitude': -30.8634,
#   'longitude': 150.7224,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 309.6,
#   'daynight': 'D',
#   'frp': 5.9,
#   'instrument': 'MODIS',
#   'latitude': -30.8649,
#   'longitude': 150.7103,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 309.8,
#   'daynight': 'D',
#   'frp': 15.6,
#   'instrument': 'MODIS',
#   'latitude': -32.7107,
#   'longitude': 147.0208,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 307.4,
#   'daynight': 'D',
#   'frp': 7.4,
#   'instrument': 'MODIS',
#   'latitude': -31.8089,
#   'longitude': 150.3822,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 312.3,
#   'daynight': 'D',
#   'frp': 12.9,
#   'instrument': 'MODIS',
#   'latitude': -29.558000000000003,
#   'longitude': 152.1505,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 317.1,
#   'daynight': 'D',
#   'frp': 20.7,
#   'instrument': 'MODIS',
#   'latitude': -30.3403,
#   'longitude': 147.721,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 313.6,
#   'daynight': 'D',
#   'frp': 10.9,
#   'instrument': 'MODIS',
#   'latitude': -30.413,
#   'longitude': 148.553,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 311.3,
#   'daynight': 'D',
#   'frp': 9.8,
#   'instrument': 'MODIS',
#   'latitude': -30.8997,
#   'longitude': 147.6905,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 305.7,
#   'daynight': 'D',
#   'frp': 6.5,
#   'instrument': 'MODIS',
#   'latitude': -30.4042,
#   'longitude': 152.0655,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 315.9,
#   'daynight': 'D',
#   'frp': 15.7,
#   'instrument': 'MODIS',
#   'latitude': -30.9441,
#   'longitude': 147.7144,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 319.7,
#   'daynight': 'D',
#   'frp': 25.3,
#   'instrument': 'MODIS',
#   'latitude': -30.9428,
#   'longitude': 147.7031,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 304.7,
#   'daynight': 'D',
#   'frp': 9.4,
#   'instrument': 'MODIS',
#   'latitude': -32.8059,
#   'longitude': 149.3534,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 310.4,
#   'daynight': 'D',
#   'frp': 16.0,
#   'instrument': 'MODIS',
#   'latitude': -32.711999999999996,
#   'longitude': 147.0259,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 341,
#   'brightness': 311.1,
#   'daynight': 'D',
#   'frp': 20.4,
#   'instrument': 'MODIS',
#   'latitude': -32.208,
#   'longitude': 146.7333,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 342,
#   'brightness': 311.9,
#   'daynight': 'D',
#   'frp': 10.3,
#   'instrument': 'MODIS',
#   'latitude': -29.5127,
#   'longitude': 148.5623,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 342,
#   'brightness': 335.3,
#   'daynight': 'D',
#   'frp': 56.0,
#   'instrument': 'MODIS',
#   'latitude': -28.0156,
#   'longitude': 148.2017,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 342,
#   'brightness': 320.8,
#   'daynight': 'D',
#   'frp': 19.6,
#   'instrument': 'MODIS',
#   'latitude': -29.088,
#   'longitude': 148.4866,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 343,
#   'brightness': 327.9,
#   'daynight': 'D',
#   'frp': 23.3,
#   'instrument': 'MODIS',
#   'latitude': -24.6606,
#   'longitude': 151.3671,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 343,
#   'brightness': 328.2,
#   'daynight': 'D',
#   'frp': 23.4,
#   'instrument': 'MODIS',
#   'latitude': -24.6682,
#   'longitude': 151.3786,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 343,
#   'brightness': 324.0,
#   'daynight': 'D',
#   'frp': 18.7,
#   'instrument': 'MODIS',
#   'latitude': -24.6578,
#   'longitude': 151.3869,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 317.8,
#   'daynight': 'D',
#   'frp': 19.6,
#   'instrument': 'MODIS',
#   'latitude': -19.4815,
#   'longitude': 146.3895,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 360.2,
#   'daynight': 'D',
#   'frp': 140.7,
#   'instrument': 'MODIS',
#   'latitude': -19.4922,
#   'longitude': 146.3912,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 340.5,
#   'daynight': 'D',
#   'frp': 68.7,
#   'instrument': 'MODIS',
#   'latitude': -19.4995,
#   'longitude': 146.4203,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 314.5,
#   'daynight': 'D',
#   'frp': 14.8,
#   'instrument': 'MODIS',
#   'latitude': -19.4927,
#   'longitude': 146.4757,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 312.2,
#   'daynight': 'D',
#   'frp': 14.4,
#   'instrument': 'MODIS',
#   'latitude': -19.5102,
#   'longitude': 146.422,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 344,
#   'brightness': 316.3,
#   'daynight': 'D',
#   'frp': 16.7,
#   'instrument': 'MODIS',
#   'latitude': -19.4939,
#   'longitude': 146.3771,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 345,
#   'brightness': 310.4,
#   'daynight': 'D',
#   'frp': 15.5,
#   'instrument': 'MODIS',
#   'latitude': -18.6816,
#   'longitude': 145.7365,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 387.4,
#   'daynight': 'D',
#   'frp': 405.8,
#   'instrument': 'MODIS',
#   'latitude': -14.8508,
#   'longitude': 144.3189,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 334.9,
#   'daynight': 'D',
#   'frp': 67.7,
#   'instrument': 'MODIS',
#   'latitude': -14.8529,
#   'longitude': 144.3027,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 325.0,
#   'daynight': 'D',
#   'frp': 61.0,
#   'instrument': 'MODIS',
#   'latitude': -13.2252,
#   'longitude': 141.9932,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 324.7,
#   'daynight': 'D',
#   'frp': 60.2,
#   'instrument': 'MODIS',
#   'latitude': -13.2352,
#   'longitude': 141.9781,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 328.1,
#   'daynight': 'D',
#   'frp': 75.9,
#   'instrument': 'MODIS',
#   'latitude': -13.2325,
#   'longitude': 142.0011,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 312.7,
#   'daynight': 'D',
#   'frp': 19.9,
#   'instrument': 'MODIS',
#   'latitude': -13.3346,
#   'longitude': 142.0185,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 316.1,
#   'daynight': 'D',
#   'frp': 24.5,
#   'instrument': 'MODIS',
#   'latitude': -13.5224,
#   'longitude': 142.6336,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 317.7,
#   'daynight': 'D',
#   'frp': 37.0,
#   'instrument': 'MODIS',
#   'latitude': -13.6289,
#   'longitude': 141.9563,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 312.8,
#   'daynight': 'D',
#   'frp': 13.4,
#   'instrument': 'MODIS',
#   'latitude': -13.5903,
#   'longitude': 142.621,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 316.1,
#   'daynight': 'D',
#   'frp': 21.2,
#   'instrument': 'MODIS',
#   'latitude': -13.5872,
#   'longitude': 142.6256,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 309.6,
#   'daynight': 'D',
#   'frp': 10.8,
#   'instrument': 'MODIS',
#   'latitude': -13.8268,
#   'longitude': 143.14,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 315.4,
#   'daynight': 'D',
#   'frp': 20.0,
#   'instrument': 'MODIS',
#   'latitude': -15.4776,
#   'longitude': 142.5811,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 309.4,
#   'daynight': 'D',
#   'frp': 12.2,
#   'instrument': 'MODIS',
#   'latitude': -15.0828,
#   'longitude': 144.9226,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 310.3,
#   'daynight': 'D',
#   'frp': 15.6,
#   'instrument': 'MODIS',
#   'latitude': -15.0421,
#   'longitude': 144.9773,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 310.1,
#   'daynight': 'D',
#   'frp': 13.9,
#   'instrument': 'MODIS',
#   'latitude': -15.0416,
#   'longitude': 144.9704,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 315.2,
#   'daynight': 'D',
#   'frp': 16.5,
#   'instrument': 'MODIS',
#   'latitude': -15.038,
#   'longitude': 144.8193,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 316.6,
#   'daynight': 'D',
#   'frp': 18.7,
#   'instrument': 'MODIS',
#   'latitude': -15.0267,
#   'longitude': 144.8179,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 315.0,
#   'daynight': 'D',
#   'frp': 18.0,
#   'instrument': 'MODIS',
#   'latitude': -15.0594,
#   'longitude': 144.4606,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 320.7,
#   'daynight': 'D',
#   'frp': 24.9,
#   'instrument': 'MODIS',
#   'latitude': -14.9914,
#   'longitude': 144.9189,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 317.3,
#   'daynight': 'D',
#   'frp': 20.2,
#   'instrument': 'MODIS',
#   'latitude': -14.9417,
#   'longitude': 144.8623,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 327.7,
#   'daynight': 'D',
#   'frp': 42.9,
#   'instrument': 'MODIS',
#   'latitude': -14.9436,
#   'longitude': 144.8472,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 330.9,
#   'daynight': 'D',
#   'frp': 52.9,
#   'instrument': 'MODIS',
#   'latitude': -14.8715,
#   'longitude': 144.408,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 323.1,
#   'daynight': 'D',
#   'frp': 30.9,
#   'instrument': 'MODIS',
#   'latitude': -14.8676,
#   'longitude': 144.3426,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 319.9,
#   'daynight': 'D',
#   'frp': 24.4,
#   'instrument': 'MODIS',
#   'latitude': -14.8695,
#   'longitude': 144.3264,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 346.4,
#   'daynight': 'D',
#   'frp': 105.5,
#   'instrument': 'MODIS',
#   'latitude': -14.8559,
#   'longitude': 144.3411,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 358.9,
#   'daynight': 'D',
#   'frp': 170.7,
#   'instrument': 'MODIS',
#   'latitude': -14.8579,
#   'longitude': 144.3248,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 341.2,
#   'daynight': 'D',
#   'frp': 86.4,
#   'instrument': 'MODIS',
#   'latitude': -14.8598,
#   'longitude': 144.3086,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 333.2,
#   'daynight': 'D',
#   'frp': 55.1,
#   'instrument': 'MODIS',
#   'latitude': -14.8443,
#   'longitude': 144.3396,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 386.6,
#   'daynight': 'D',
#   'frp': 395.1,
#   'instrument': 'MODIS',
#   'latitude': -14.8462,
#   'longitude': 144.3233,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 365.4,
#   'daynight': 'D',
#   'frp': 214.6,
#   'instrument': 'MODIS',
#   'latitude': -14.8481,
#   'longitude': 144.30700000000002,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 346,
#   'brightness': 349.2,
#   'daynight': 'D',
#   'frp': 122.3,
#   'instrument': 'MODIS',
#   'latitude': -14.8488,
#   'longitude': 144.3351,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 347,
#   'brightness': 312.3,
#   'daynight': 'D',
#   'frp': 21.5,
#   'instrument': 'MODIS',
#   'latitude': -11.7949,
#   'longitude': 142.0856,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 347,
#   'brightness': 315.8,
#   'daynight': 'D',
#   'frp': 30.9,
#   'instrument': 'MODIS',
#   'latitude': -12.017999999999999,
#   'longitude': 141.8599,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 347,
#   'brightness': 312.4,
#   'daynight': 'D',
#   'frp': 21.4,
#   'instrument': 'MODIS',
#   'latitude': -11.8598,
#   'longitude': 142.1847,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 328.2,
#   'daynight': 'D',
#   'frp': 104.3,
#   'instrument': 'MODIS',
#   'latitude': -33.7971,
#   'longitude': 120.7667,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 307.1,
#   'daynight': 'D',
#   'frp': 24.2,
#   'instrument': 'MODIS',
#   'latitude': -33.3438,
#   'longitude': 120.8919,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 303.3,
#   'daynight': 'D',
#   'frp': 15.0,
#   'instrument': 'MODIS',
#   'latitude': -33.3513,
#   'longitude': 120.8858,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 303.5,
#   'daynight': 'D',
#   'frp': 15.7,
#   'instrument': 'MODIS',
#   'latitude': -33.3014,
#   'longitude': 120.9884,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 315.6,
#   'daynight': 'D',
#   'frp': 53.2,
#   'instrument': 'MODIS',
#   'latitude': -33.7994,
#   'longitude': 120.7996,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 519,
#   'brightness': 336.0,
#   'daynight': 'D',
#   'frp': 145.8,
#   'instrument': 'MODIS',
#   'latitude': -33.8013,
#   'longitude': 120.7719,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 521,
#   'brightness': 317.4,
#   'daynight': 'D',
#   'frp': 8.9,
#   'instrument': 'MODIS',
#   'latitude': -26.1473,
#   'longitude': 129.3442,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 352.4,
#   'daynight': 'D',
#   'frp': 59.2,
#   'instrument': 'MODIS',
#   'latitude': -22.2687,
#   'longitude': 124.8861,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 319.1,
#   'daynight': 'D',
#   'frp': 6.7,
#   'instrument': 'MODIS',
#   'latitude': -22.9423,
#   'longitude': 128.2021,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 322.0,
#   'daynight': 'D',
#   'frp': 9.8,
#   'instrument': 'MODIS',
#   'latitude': -22.9439,
#   'longitude': 128.1919,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 325.7,
#   'daynight': 'D',
#   'frp': 11.7,
#   'instrument': 'MODIS',
#   'latitude': -22.2645,
#   'longitude': 124.9169,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 328.3,
#   'daynight': 'D',
#   'frp': 15.0,
#   'instrument': 'MODIS',
#   'latitude': -22.2659,
#   'longitude': 124.9067,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 341.5,
#   'daynight': 'D',
#   'frp': 35.6,
#   'instrument': 'MODIS',
#   'latitude': -22.2673,
#   'longitude': 124.8964,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 522,
#   'brightness': 334.3,
#   'daynight': 'D',
#   'frp': 24.1,
#   'instrument': 'MODIS',
#   'latitude': -22.2701,
#   'longitude': 124.8758,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 523,
#   'brightness': 328.9,
#   'daynight': 'D',
#   'frp': 45.8,
#   'instrument': 'MODIS',
#   'latitude': -20.7789,
#   'longitude': 119.4428,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 523,
#   'brightness': 337.7,
#   'daynight': 'D',
#   'frp': 81.1,
#   'instrument': 'MODIS',
#   'latitude': -20.7918,
#   'longitude': 119.4444,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 523,
#   'brightness': 332.6,
#   'daynight': 'D',
#   'frp': 57.3,
#   'instrument': 'MODIS',
#   'latitude': -20.7941,
#   'longitude': 119.4234,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 523,
#   'brightness': 326.9,
#   'daynight': 'D',
#   'frp': 37.6,
#   'instrument': 'MODIS',
#   'latitude': -20.7811,
#   'longitude': 119.4219,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 325.6,
#   'daynight': 'D',
#   'frp': 26.4,
#   'instrument': 'MODIS',
#   'latitude': -15.1927,
#   'longitude': 130.34,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 324.0,
#   'daynight': 'D',
#   'frp': 8.5,
#   'instrument': 'MODIS',
#   'latitude': -16.9071,
#   'longitude': 122.7686,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.7,
#   'daynight': 'D',
#   'frp': 28.2,
#   'instrument': 'MODIS',
#   'latitude': -15.4903,
#   'longitude': 130.6806,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 333.7,
#   'daynight': 'D',
#   'frp': 42.5,
#   'instrument': 'MODIS',
#   'latitude': -15.5022,
#   'longitude': 130.6125,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 337.4,
#   'daynight': 'D',
#   'frp': 56.7,
#   'instrument': 'MODIS',
#   'latitude': -15.5052,
#   'longitude': 130.5955,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.8,
#   'daynight': 'D',
#   'frp': 28.9,
#   'instrument': 'MODIS',
#   'latitude': -15.5081,
#   'longitude': 130.5788,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.1,
#   'daynight': 'D',
#   'frp': 28.5,
#   'instrument': 'MODIS',
#   'latitude': -15.511,
#   'longitude': 130.562,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.2,
#   'daynight': 'D',
#   'frp': 28.7,
#   'instrument': 'MODIS',
#   'latitude': -15.5139,
#   'longitude': 130.5452,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.0,
#   'daynight': 'D',
#   'frp': 36.9,
#   'instrument': 'MODIS',
#   'latitude': -15.5012,
#   'longitude': 130.6593,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.6,
#   'daynight': 'D',
#   'frp': 29.2,
#   'instrument': 'MODIS',
#   'latitude': -15.5041,
#   'longitude': 130.6423,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 327.4,
#   'daynight': 'D',
#   'frp': 24.6,
#   'instrument': 'MODIS',
#   'latitude': -15.5069,
#   'longitude': 130.6255,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 334.3,
#   'daynight': 'D',
#   'frp': 46.1,
#   'instrument': 'MODIS',
#   'latitude': -15.5097,
#   'longitude': 130.6084,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.0,
#   'daynight': 'D',
#   'frp': 35.5,
#   'instrument': 'MODIS',
#   'latitude': -15.5126,
#   'longitude': 130.5914,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 327.0,
#   'daynight': 'D',
#   'frp': 23.0,
#   'instrument': 'MODIS',
#   'latitude': -15.4905,
#   'longitude': 130.4331,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 337.2,
#   'daynight': 'D',
#   'frp': 56.8,
#   'instrument': 'MODIS',
#   'latitude': -15.4755,
#   'longitude': 130.3795,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 327.3,
#   'daynight': 'D',
#   'frp': 11.5,
#   'instrument': 'MODIS',
#   'latitude': -16.1733,
#   'longitude': 126.0054,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 352.8,
#   'daynight': 'D',
#   'frp': 55.7,
#   'instrument': 'MODIS',
#   'latitude': -16.1747,
#   'longitude': 125.99600000000001,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 346.6,
#   'daynight': 'D',
#   'frp': 91.1,
#   'instrument': 'MODIS',
#   'latitude': -15.4381,
#   'longitude': 130.5266,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 345.3,
#   'daynight': 'D',
#   'frp': 84.8,
#   'instrument': 'MODIS',
#   'latitude': -15.440999999999999,
#   'longitude': 130.5098,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.0,
#   'daynight': 'D',
#   'frp': 15.8,
#   'instrument': 'MODIS',
#   'latitude': -16.1643,
#   'longitude': 126.00399999999999,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 332.8,
#   'daynight': 'D',
#   'frp': 36.5,
#   'instrument': 'MODIS',
#   'latitude': -15.4292,
#   'longitude': 130.5077,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.5,
#   'daynight': 'D',
#   'frp': 32.8,
#   'instrument': 'MODIS',
#   'latitude': -15.4435,
#   'longitude': 130.5206,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 357.6,
#   'daynight': 'D',
#   'frp': 152.4,
#   'instrument': 'MODIS',
#   'latitude': -15.4317,
#   'longitude': 130.5184,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.6,
#   'daynight': 'D',
#   'frp': 23.8,
#   'instrument': 'MODIS',
#   'latitude': -15.4345,
#   'longitude': 130.5017,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.9,
#   'daynight': 'D',
#   'frp': 37.8,
#   'instrument': 'MODIS',
#   'latitude': -15.3797,
#   'longitude': 130.7558,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 345.3,
#   'daynight': 'D',
#   'frp': 83.2,
#   'instrument': 'MODIS',
#   'latitude': -15.4227,
#   'longitude': 130.4995,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 353.2,
#   'daynight': 'D',
#   'frp': 123.9,
#   'instrument': 'MODIS',
#   'latitude': -15.4109,
#   'longitude': 130.4973,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 345.1,
#   'daynight': 'D',
#   'frp': 83.0,
#   'instrument': 'MODIS',
#   'latitude': -15.4137,
#   'longitude': 130.4806,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 327.1,
#   'daynight': 'D',
#   'frp': 24.3,
#   'instrument': 'MODIS',
#   'latitude': -15.3556,
#   'longitude': 130.7514,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.7,
#   'daynight': 'D',
#   'frp': 28.3,
#   'instrument': 'MODIS',
#   'latitude': -15.4019,
#   'longitude': 130.4785,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 325.2,
#   'daynight': 'D',
#   'frp': 20.9,
#   'instrument': 'MODIS',
#   'latitude': -15.4047,
#   'longitude': 130.4618,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 328.9,
#   'daynight': 'D',
#   'frp': 30.9,
#   'instrument': 'MODIS',
#   'latitude': -15.392999999999999,
#   'longitude': 130.4597,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 327.9,
#   'daynight': 'D',
#   'frp': 12.4,
#   'instrument': 'MODIS',
#   'latitude': -16.09,
#   'longitude': 126.005,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 337.3,
#   'daynight': 'D',
#   'frp': 25.2,
#   'instrument': 'MODIS',
#   'latitude': -16.0914,
#   'longitude': 125.9955,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 322.7,
#   'daynight': 'D',
#   'frp': 23.4,
#   'instrument': 'MODIS',
#   'latitude': -15.2073,
#   'longitude': 131.3123,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 323.7,
#   'daynight': 'D',
#   'frp': 7.1,
#   'instrument': 'MODIS',
#   'latitude': -16.0831,
#   'longitude': 125.9264,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 341.2,
#   'daynight': 'D',
#   'frp': 31.5,
#   'instrument': 'MODIS',
#   'latitude': -16.0845,
#   'longitude': 125.9169,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 333.1,
#   'daynight': 'D',
#   'frp': 19.2,
#   'instrument': 'MODIS',
#   'latitude': -16.0859,
#   'longitude': 125.9075,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 324.0,
#   'daynight': 'D',
#   'frp': 8.6,
#   'instrument': 'MODIS',
#   'latitude': -16.0873,
#   'longitude': 125.8981,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 323.1,
#   'daynight': 'D',
#   'frp': 23.3,
#   'instrument': 'MODIS',
#   'latitude': -15.2051,
#   'longitude': 131.252,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
#   'acq_time': 524,
#   'brightness': 331.3,
#   'daynight': 'D',
#   'frp': 16.3,
#   'instrument': 'MODIS',
#   'latitude': -16.0754,
#   'longitude': 125.9155,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-01',
# ...
#   'acq_time': 429,
#   'brightness': 320.5,
#   'daynight': 'D',
#   'frp': 18.9,
#   'instrument': 'MODIS',
#   'latitude': -13.0663,
#   'longitude': 132.9043,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 322.9,
#   'daynight': 'D',
#   'frp': 17.7,
#   'instrument': 'MODIS',
#   'latitude': -12.8923,
#   'longitude': 134.2293,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 319.2,
#   'daynight': 'D',
#   'frp': 11.3,
#   'instrument': 'MODIS',
#   'latitude': -12.8999,
#   'longitude': 134.225,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 318.6,
#   'daynight': 'D',
#   'frp': 10.3,
#   'instrument': 'MODIS',
#   'latitude': -12.8875,
#   'longitude': 134.2366,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 318.9,
#   'daynight': 'D',
#   'frp': 10.7,
#   'instrument': 'MODIS',
#   'latitude': -12.8892,
#   'longitude': 134.2234,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 315.1,
#   'daynight': 'D',
#   'frp': 7.2,
#   'instrument': 'MODIS',
#   'latitude': -12.644,
#   'longitude': 135.8332,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 317.5,
#   'daynight': 'D',
#   'frp': 8.3,
#   'instrument': 'MODIS',
#   'latitude': -12.8036,
#   'longitude': 134.6308,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.7,
#   'daynight': 'D',
#   'frp': 15.3,
#   'instrument': 'MODIS',
#   'latitude': -12.8062,
#   'longitude': 134.529,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 328.8,
#   'daynight': 'D',
#   'frp': 29.5,
#   'instrument': 'MODIS',
#   'latitude': -12.8311,
#   'longitude': 134.3361,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 315.0,
#   'daynight': 'D',
#   'frp': 6.8,
#   'instrument': 'MODIS',
#   'latitude': -12.5929,
#   'longitude': 135.9226,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 317.5,
#   'daynight': 'D',
#   'frp': 9.7,
#   'instrument': 'MODIS',
#   'latitude': -12.811,
#   'longitude': 134.2393,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 323.6,
#   'daynight': 'D',
#   'frp': 14.2,
#   'instrument': 'MODIS',
#   'latitude': -12.7628,
#   'longitude': 134.5358,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 316.5,
#   'daynight': 'D',
#   'frp': 8.8,
#   'instrument': 'MODIS',
#   'latitude': -12.8444,
#   'longitude': 133.8835,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.8,
#   'daynight': 'D',
#   'frp': 17.2,
#   'instrument': 'MODIS',
#   'latitude': -12.7673,
#   'longitude': 134.5298,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 319.7,
#   'daynight': 'D',
#   'frp': 15.1,
#   'instrument': 'MODIS',
#   'latitude': -12.8408,
#   'longitude': 133.8905,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.3,
#   'daynight': 'D',
#   'frp': 9.9,
#   'instrument': 'MODIS',
#   'latitude': -12.7463,
#   'longitude': 134.52700000000002,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.0,
#   'daynight': 'D',
#   'frp': 14.4,
#   'instrument': 'MODIS',
#   'latitude': -12.751,
#   'longitude': 134.4106,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 322.6,
#   'daynight': 'D',
#   'frp': 17.3,
#   'instrument': 'MODIS',
#   'latitude': -12.7526,
#   'longitude': 134.3978,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 326.9,
#   'daynight': 'D',
#   'frp': 27.1,
#   'instrument': 'MODIS',
#   'latitude': -12.7388,
#   'longitude': 134.1686,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 326.2,
#   'daynight': 'D',
#   'frp': 26.6,
#   'instrument': 'MODIS',
#   'latitude': -12.775,
#   'longitude': 133.8818,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 320.4,
#   'daynight': 'D',
#   'frp': 14.7,
#   'instrument': 'MODIS',
#   'latitude': -12.7768,
#   'longitude': 133.8676,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 342.4,
#   'daynight': 'D',
#   'frp': 68.8,
#   'instrument': 'MODIS',
#   'latitude': -12.764000000000001,
#   'longitude': 133.8803,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 333.9,
#   'daynight': 'D',
#   'frp': 43.5,
#   'instrument': 'MODIS',
#   'latitude': -12.7658,
#   'longitude': 133.8661,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.7,
#   'daynight': 'D',
#   'frp': 17.1,
#   'instrument': 'MODIS',
#   'latitude': -12.8821,
#   'longitude': 132.9191,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 331.9,
#   'daynight': 'D',
#   'frp': 45.7,
#   'instrument': 'MODIS',
#   'latitude': -12.7724,
#   'longitude': 133.7222,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 317.9,
#   'daynight': 'D',
#   'frp': 16.1,
#   'instrument': 'MODIS',
#   'latitude': -12.7742,
#   'longitude': 133.7079,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 335.7,
#   'daynight': 'D',
#   'frp': 47.2,
#   'instrument': 'MODIS',
#   'latitude': -12.7631,
#   'longitude': 133.8747,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 333.6,
#   'daynight': 'D',
#   'frp': 50.5,
#   'instrument': 'MODIS',
#   'latitude': -12.7725,
#   'longitude': 133.717,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 320.7,
#   'daynight': 'D',
#   'frp': 14.8,
#   'instrument': 'MODIS',
#   'latitude': -12.7393,
#   'longitude': 133.886,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 326.3,
#   'daynight': 'D',
#   'frp': 26.0,
#   'instrument': 'MODIS',
#   'latitude': -12.7265,
#   'longitude': 133.8984,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 322.5,
#   'daynight': 'D',
#   'frp': 13.9,
#   'instrument': 'MODIS',
#   'latitude': -12.65,
#   'longitude': 134.4044,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 324.8,
#   'daynight': 'D',
#   'frp': 22.4,
#   'instrument': 'MODIS',
#   'latitude': -12.6963,
#   'longitude': 134.0472,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 329.6,
#   'daynight': 'D',
#   'frp': 32.6,
#   'instrument': 'MODIS',
#   'latitude': -12.698,
#   'longitude': 134.034,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 318.0,
#   'daynight': 'D',
#   'frp': 10.7,
#   'instrument': 'MODIS',
#   'latitude': -12.3632,
#   'longitude': 136.47799999999998,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.4,
#   'daynight': 'D',
#   'frp': 16.0,
#   'instrument': 'MODIS',
#   'latitude': -12.6854,
#   'longitude': 134.046,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.6,
#   'daynight': 'D',
#   'frp': 23.5,
#   'instrument': 'MODIS',
#   'latitude': -12.7028,
#   'longitude': 133.9095,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 317.2,
#   'daynight': 'D',
#   'frp': 15.3,
#   'instrument': 'MODIS',
#   'latitude': -12.8309,
#   'longitude': 132.8914,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 327.4,
#   'daynight': 'D',
#   'frp': 28.2,
#   'instrument': 'MODIS',
#   'latitude': -12.6919,
#   'longitude': 133.908,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 319.7,
#   'daynight': 'D',
#   'frp': 9.3,
#   'instrument': 'MODIS',
#   'latitude': -12.6167,
#   'longitude': 134.4128,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 328.7,
#   'daynight': 'D',
#   'frp': 32.5,
#   'instrument': 'MODIS',
#   'latitude': -12.681,
#   'longitude': 133.9063,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 322.4,
#   'daynight': 'D',
#   'frp': 19.5,
#   'instrument': 'MODIS',
#   'latitude': -12.6828,
#   'longitude': 133.8923,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.9,
#   'daynight': 'D',
#   'frp': 20.3,
#   'instrument': 'MODIS',
#   'latitude': -12.4791,
#   'longitude': 134.9263,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 337.0,
#   'daynight': 'D',
#   'frp': 145.6,
#   'instrument': 'MODIS',
#   'latitude': -13.0497,
#   'longitude': 130.1548,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.5,
#   'daynight': 'D',
#   'frp': 15.2,
#   'instrument': 'MODIS',
#   'latitude': -12.6087,
#   'longitude': 133.6594,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 326.4,
#   'daynight': 'D',
#   'frp': 14.0,
#   'instrument': 'MODIS',
#   'latitude': -15.7992,
#   'longitude': 137.0737,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 343.0,
#   'daynight': 'D',
#   'frp': 41.7,
#   'instrument': 'MODIS',
#   'latitude': -15.8006,
#   'longitude': 137.0636,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 334.3,
#   'daynight': 'D',
#   'frp': 26.3,
#   'instrument': 'MODIS',
#   'latitude': -15.8019,
#   'longitude': 137.0535,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 353.2,
#   'daynight': 'D',
#   'frp': 62.4,
#   'instrument': 'MODIS',
#   'latitude': -15.7884,
#   'longitude': 137.0825,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 333.5,
#   'daynight': 'D',
#   'frp': 22.4,
#   'instrument': 'MODIS',
#   'latitude': -15.7898,
#   'longitude': 137.0724,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 329.4,
#   'daynight': 'D',
#   'frp': 16.6,
#   'instrument': 'MODIS',
#   'latitude': -15.7926,
#   'longitude': 137.0521,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 335.0,
#   'daynight': 'D',
#   'frp': 24.4,
#   'instrument': 'MODIS',
#   'latitude': -15.7738,
#   'longitude': 137.0494,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 341.4,
#   'daynight': 'D',
#   'frp': 37.2,
#   'instrument': 'MODIS',
#   'latitude': -15.7644,
#   'longitude': 137.048,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 327.9,
#   'daynight': 'D',
#   'frp': 15.4,
#   'instrument': 'MODIS',
#   'latitude': -15.7658,
#   'longitude': 137.0378,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 342.1,
#   'daynight': 'D',
#   'frp': 39.2,
#   'instrument': 'MODIS',
#   'latitude': -15.7564,
#   'longitude': 137.0365,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 322.4,
#   'daynight': 'D',
#   'frp': 10.6,
#   'instrument': 'MODIS',
#   'latitude': -15.7457,
#   'longitude': 137.0453,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.2,
#   'daynight': 'D',
#   'frp': 14.4,
#   'instrument': 'MODIS',
#   'latitude': -15.747,
#   'longitude': 137.0351,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.6,
#   'daynight': 'D',
#   'frp': 63.6,
#   'instrument': 'MODIS',
#   'latitude': -15.5166,
#   'longitude': 130.6377,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 325.6,
#   'daynight': 'D',
#   'frp': 61.1,
#   'instrument': 'MODIS',
#   'latitude': -15.5195,
#   'longitude': 130.6099,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 326.5,
#   'daynight': 'D',
#   'frp': 67.1,
#   'instrument': 'MODIS',
#   'latitude': -15.5169,
#   'longitude': 130.6327,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 324.1,
#   'daynight': 'D',
#   'frp': 52.1,
#   'instrument': 'MODIS',
#   'latitude': -15.52,
#   'longitude': 130.6049,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 320.3,
#   'daynight': 'D',
#   'frp': 24.9,
#   'instrument': 'MODIS',
#   'latitude': -15.4224,
#   'longitude': 130.5288,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 331.5,
#   'daynight': 'D',
#   'frp': 34.9,
#   'instrument': 'MODIS',
#   'latitude': -13.8788,
#   'longitude': 141.9627,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 321.3,
#   'daynight': 'D',
#   'frp': 32.5,
#   'instrument': 'MODIS',
#   'latitude': -15.3831,
#   'longitude': 130.7473,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 347.7,
#   'daynight': 'D',
#   'frp': 213.2,
#   'instrument': 'MODIS',
#   'latitude': -15.3656,
#   'longitude': 130.7722,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 346.2,
#   'daynight': 'D',
#   'frp': 197.1,
#   'instrument': 'MODIS',
#   'latitude': -15.3686,
#   'longitude': 130.7454,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 332.8,
#   'daynight': 'D',
#   'frp': 98.2,
#   'instrument': 'MODIS',
#   'latitude': -15.350999999999999,
#   'longitude': 130.7704,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 339.3,
#   'daynight': 'D',
#   'frp': 141.6,
#   'instrument': 'MODIS',
#   'latitude': -15.354000000000001,
#   'longitude': 130.7436,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 324.6,
#   'daynight': 'D',
#   'frp': 18.9,
#   'instrument': 'MODIS',
#   'latitude': -13.8241,
#   'longitude': 141.9782,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 429,
#   'brightness': 330.7,
#   'daynight': 'D',
#   'frp': 29.2,
#   'instrument': 'MODIS',
#   'latitude': -13.8139,
#   'longitude': 141.9765,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 321.5,
#   'daynight': 'D',
#   'frp': 10.8,
#   'instrument': 'MODIS',
#   'latitude': -12.2628,
#   'longitude': 135.4745,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 332.2,
#   'daynight': 'D',
#   'frp': 112.2,
#   'instrument': 'MODIS',
#   'latitude': -13.05,
#   'longitude': 130.1499,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 320.1,
#   'daynight': 'D',
#   'frp': 15.1,
#   'instrument': 'MODIS',
#   'latitude': -12.609000000000002,
#   'longitude': 133.6542,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 317.6,
#   'daynight': 'D',
#   'frp': 21.6,
#   'instrument': 'MODIS',
#   'latitude': -11.2935,
#   'longitude': 131.9438,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 334.4,
#   'daynight': 'D',
#   'frp': 113.5,
#   'instrument': 'MODIS',
#   'latitude': -11.632,
#   'longitude': 130.3646,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 327.3,
#   'daynight': 'D',
#   'frp': 69.4,
#   'instrument': 'MODIS',
#   'latitude': -11.6463,
#   'longitude': 130.3664,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 325.4,
#   'daynight': 'D',
#   'frp': 61.2,
#   'instrument': 'MODIS',
#   'latitude': -11.6388,
#   'longitude': 130.3471,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 338.3,
#   'daynight': 'D',
#   'frp': 137.1,
#   'instrument': 'MODIS',
#   'latitude': -11.6359,
#   'longitude': 130.372,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 326.6,
#   'daynight': 'D',
#   'frp': 69.2,
#   'instrument': 'MODIS',
#   'latitude': -11.6746,
#   'longitude': 130.6479,
#   'satellite': 'Aqua'},
#  {'acq_date': '2019-08-02',
#   'acq_time': 430,
#   'brightness': 322.6,
#   'daynight': 'D',
#   'frp': 50.2,
#   'instrument': 'MODIS',
#   'latitude': -11.6717,
#   'longitude': 130.6717,
#   'satellite': 'Aqua'},
#  ...]

# %% [markdown]
# ## Load into database

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client['test']

# %%
collection = db.fires_from_space

# %%
collection.insert_many(fires_from_space)

# Loop through the list of fires and insert into database in chunks.
# print("Beginning load into database.")
# print("--------------------------------------------")
# count = 0
# set = 1
# for idx, fire in enumerate(fires_from_space):
#     count = count + 1
#     # To avoid inserting so many at once and slowing down the database, insert fire data 50 at a time.
#     # then sleep for 5 seconds, and then continue with next 50 fires and so on...
#     if count == 51:
#         count = 1
#         set = set + 1
#         time.sleep(5)
#     print(f"Processing Record {count} of Set {set}")
#     try:
#         collection.insert_one(fire)
#     except:
#         print("Unable to insert fire data into database. Skipping...")
        
# print("------------------------------------------------")
# print("Loading data into database is complete")
# print("------------------------------------------------")
