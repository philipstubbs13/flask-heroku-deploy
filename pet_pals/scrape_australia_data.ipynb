# %% [markdown]
# ## Dependencies

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
import pandas as pd
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
import requests
import numpy as np

# %% [markdown]
# ## Windows

# %%
executable_path = {"executable_path": "chromedriver.exe"}

def init_browser():
    executable_path = {"executable_path": "chromedriver.exe"}
    return Browser("chrome", **executable_path, headless=False)

browser = init_browser()

# %% [markdown]
# ## Mac

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## 2019–20 Australian bushfire season
#
# Scrape data related to the 2019-2020 Australian bushfire season from the following site: <https://en.wikipedia.org/wiki/2019%E2%80%9320_Australian_bushfire_season>

# %%
# Visit url.
url = "https://en.wikipedia.org/wiki/2019%E2%80%9320_Australian_bushfire_season"
browser.visit(url)

# Wait for page/page elements to load.
time.sleep(1)

# Scrape page into soup.
html = browser.html
soup = bs(html, "html.parser")

# Get table data using pandas.
tables = pd.read_html(url)
tables[1]
# Out:
#               State / territory Fatalities Homeslost Area(estimated)  \
#               State / territory Fatalities Homeslost              ha
# 0  Australian Capital Territory          1         0           56688
# 1               New South Wales         25      2439         5400000
# 2            Northern Territory          0         5         6800000
# 3                    Queensland          0        48         2500000
# 4               South Australia          3       151          490000
# 5                      Tasmania          0         2           36000
# 6                      Victoria          5       396         1500000
# 7             Western Australia          0         1         2200000
# 8                         Total         34    3,500+        18736070
#
#                                                          Notes
#       acres                                              Notes
# 0    140080                  Area;[91][92][93] fatality[c][95]
# 1  13300000            Area;[96] fatalities;[18][37] homes[96]
# 2  16800000  Area, includes mainly scrub fires, which are w...
# 3   6180000       Area, includes scrub fires;[49] homes[97][d]
# 4   1210000  Area;[49] fatalities;[102] homes (KI:65)[103] ...
# 5     89000                                Area;[49] homes[97]
# 6   3710000               Area;[49] fatalities;[15] homes[105]
# 7   5440000          Area, includes scrub fires;[49] homes[97]
# 8  46300000  [e][b][109][110] Total area estimate as of 13 ...

# %%
# Convert table from website to pandas dataframe.
australia_fire_2019_df = tables[1]
australia_fire_2019_df.columns = ["state", "fatalities", "homes_lost", "area_ha", "area_acres", "notes"]

australia_fire_2019_df
# Out:
#                           state  fatalities homes_lost   area_ha  area_acres  \
# 0  Australian Capital Territory           1          0     56688      140080
# 1               New South Wales          25       2439   5400000    13300000
# 2            Northern Territory           0          5   6800000    16800000
# 3                    Queensland           0         48   2500000     6180000
# 4               South Australia           3        151    490000     1210000
# 5                      Tasmania           0          2     36000       89000
# 6                      Victoria           5        396   1500000     3710000
# 7             Western Australia           0          1   2200000     5440000
# 8                         Total          34     3,500+  18736070    46300000
#
#                                                notes
# 0                  Area;[91][92][93] fatality[c][95]
# 1            Area;[96] fatalities;[18][37] homes[96]
# 2  Area, includes mainly scrub fires, which are w...
# 3       Area, includes scrub fires;[49] homes[97][d]
# 4  Area;[49] fatalities;[102] homes (KI:65)[103] ...
# 5                                Area;[49] homes[97]
# 6               Area;[49] fatalities;[15] homes[105]
# 7          Area, includes scrub fires;[49] homes[97]
# 8  [e][b][109][110] Total area estimate as of 13 ...

# %%
# Remove the notes column
del australia_fire_2019_df['notes']

australia_fire_2019_df
# Out:
#                           state  fatalities homes_lost   area_ha  area_acres
# 0  Australian Capital Territory           1          0     56688      140080
# 1               New South Wales          25       2439   5400000    13300000
# 2            Northern Territory           0          5   6800000    16800000
# 3                    Queensland           0         48   2500000     6180000
# 4               South Australia           3        151    490000     1210000
# 5                      Tasmania           0          2     36000       89000
# 6                      Victoria           5        396   1500000     3710000
# 7             Western Australia           0          1   2200000     5440000
# 8                         Total          34     3,500+  18736070    46300000

# %%
# Drop the totals row
australia_fire_2019_df = australia_fire_2019_df[australia_fire_2019_df.state != 'Total']

australia_fire_2019_df
# Out:
#                           state  fatalities homes_lost  area_ha  area_acres
# 0  Australian Capital Territory           1          0    56688      140080
# 1               New South Wales          25       2439  5400000    13300000
# 2            Northern Territory           0          5  6800000    16800000
# 3                    Queensland           0         48  2500000     6180000
# 4               South Australia           3        151   490000     1210000
# 5                      Tasmania           0          2    36000       89000
# 6                      Victoria           5        396  1500000     3710000
# 7             Western Australia           0          1  2200000     5440000

# %%
# Check data types

# Change homes_lost column from type string to type int.
australia_fire_2019_df["homes_lost"] = australia_fire_2019_df["homes_lost"].astype(int)

australia_fire_2019_df.dtypes
# Out:
# state         object
# fatalities     int64
# homes_lost     int32
# area_ha        int64
# area_acres     int64
# dtype: object

# %%
# Check for null values
australia_fire_2019_df.count()
# Out:
# state         8
# fatalities    8
# homes_lost    8
# area_ha       8
# area_acres    8
# dtype: int64

# %%
# Convert dataframe to dictionary.
# https://stackoverflow.com/questions/26716616/convert-a-pandas-dataframe-to-a-dictionary
australia_fire_2019_dict = australia_fire_2019_df.to_dict('range')

australia_fire_2019_dict
# Out:
# [{'state': 'Australian Capital Territory',
#   'fatalities': 1,
#   'homes_lost': 0,
#   'area_ha': 56688,
#   'area_acres': 140080},
#  {'state': 'New South Wales',
#   'fatalities': 25,
#   'homes_lost': 2439,
#   'area_ha': 5400000,
#   'area_acres': 13300000},
#  {'state': 'Northern Territory',
#   'fatalities': 0,
#   'homes_lost': 5,
#   'area_ha': 6800000,
#   'area_acres': 16800000},
#  {'state': 'Queensland',
#   'fatalities': 0,
#   'homes_lost': 48,
#   'area_ha': 2500000,
#   'area_acres': 6180000},
#  {'state': 'South Australia',
#   'fatalities': 3,
#   'homes_lost': 151,
#   'area_ha': 490000,
#   'area_acres': 1210000},
#  {'state': 'Tasmania',
#   'fatalities': 0,
#   'homes_lost': 2,
#   'area_ha': 36000,
#   'area_acres': 89000},
#  {'state': 'Victoria',
#   'fatalities': 5,
#   'homes_lost': 396,
#   'area_ha': 1500000,
#   'area_acres': 3710000},
#  {'state': 'Western Australia',
#   'fatalities': 0,
#   'homes_lost': 1,
#   'area_ha': 2200000,
#   'area_acres': 5440000}]

# %% [markdown]
# ## List of major bushfires in Australia
#
# Scrape data related to past Australian bushfire seasons from the following site:
# <https://en.wikipedia.org/wiki/List_of_major_bushfires_in_Australia>

# %%
# Visit url.
url = requests.get("https://en.wikipedia.org/wiki/List_of_major_bushfires_in_Australia").text

# Wait for page/page elements to load.
time.sleep(1)

# Scrape page into soup.
soup = bs(url, "lxml")

# %%
table = soup.findAll('table')[0]
table.tbody.findAll('tr')

dates = []
names = []
states = []
area_ha = []
area_acres = []
fatalities = []
homes_destroyed = []

for row in soup.findAll('table')[0].tbody.findAll('tr'):
    try:
        dates.append(row.findAll('td')[0].text.rstrip("\n"))
        names.append(row.findAll('td')[1].text.rstrip("\n"))
        states.append(row.findAll('td')[2].text.rstrip("\n"))
        area_ha.append(row.findAll('td')[3].text.rstrip("\n"))
        area_acres.append(row.findAll('td')[4].text.rstrip("\n"))
        fatalities.append(row.findAll('td')[5].text.rstrip("\n"))
        homes_destroyed.append(row.findAll('td')[6].text.rstrip("\n"))
    except:
        print('This is a header row.')

australia_fire_seasons_dict = {
    "date": dates,
    "name": names,
    "state": states,
    "area_ha": area_ha,
    "area_acres": area_acres,
    "fatalities": fatalities,
    "homes_destroyed": homes_destroyed,
}

print(australia_fire_seasons_dict)
# Out:
# This is a header row.
# This is a header row.
# {'date': ['6 February 1851', '1 February 1898', 'February – March 1926', 'December 1938 – January 1939', '14 January – 14 February 1944', '18 November 1944', 'November 1951 – January 1952', '2 January 1955', '30 November 1957', '2 December 1957', 'January – March 1961', '14 – 16 January 1962', '16 February – 13 March 1965', '5 – 14 March 1965', '7 February 1967', '1968 – 69[clarification needed]', '29 November 1968', '8 January 1969', '1969 – 70[clarification needed]', '1974 – 1975 summer fire season(defined as October 1974 to February 1975 in Queensland only)', '12 February 1977', '17 December 1977', '4 April 1978', 'December 1979', '3 November 1980', '9 January 1983', '16 February 1983', '25 December 1984', 'Mid-January 1985', '1984 – 1985 season[clarification needed]', '14 January 1985', '27 December 1993 – 16 January 1994', '8 January 1997', '21 January 1997', '2 December 1997', '2 December 1997', '2 December 1997', '2 December 1998', '25 December 2001 – 7 January 2002', 'August – November 2002', '18 – 22 January 2003', '8 January – 8 March 2003', 'December 2003', '10 – 12 January 2005', 'New Years Day 2006', 'December 2005 – January 2006', 'January 2006', '6 February 2006', '1 December 2006 –  March 2007', 'September 2006 – January 2007', '4 February 2007', '6 – 14 December 2007', '30 December 2007', '7 February – 14 March 2009', '4 January 2013', '18 January 2013', '17 – 28 October 2013', '27 December 2011 – 3 February 2012', '2 – 9 January 2015', '29 January – 20 February 2015', 'January 2015', 'October – November 2015', '15 – 24 November 2015', '25 November – 2 December 2015', 'January 2016', '11 – 14 February 2017', 'early February 2019', '5 September 2019 – present'], 'name': ['Black Thursday bushfires', 'Red Tuesday bushfires', '1926 bushfires', 'Black Friday bushfires', '1944 Victorian bushfires', '1944 Blue Mountains bushfire', '1951–52 bushfires', 'Black Sunday bushfires', '1957 Grose Valley bushfire, Blue Mountains', '1957 Leura bushfire, Blue Mountains', '1961 Western Australian bushfires', '1962 Victorian bushfires', '1965 Gippsland bushfires', 'Southern Highlands bushfires', 'Black Tuesday bushfires', '1968-69 Killarney Top Springs bushfires', '1968 Blue Mountains Bushfire', '1969 bushfires', '1969-70 Dry River-Victoria River fire', '1974-75 Australian bushfire season[d]', 'Western Districts bushfires', 'Blue Mountains Fires 1977', '1978 Western Australian bushfires', '1979 Sydney bushfires', '1980 Waterfall bushfire', 'Grays Point bushfire', 'Ash Wednesday bushfires', '1984 Western New South Wales grasslands bushfires', '1985 Cobar bushfire', '1984 - 85 New South Wales bushfires', 'Central Victoria bushfires', '1994 Eastern seaboard fires', 'Wooroloo bushfire', 'Dandenongs bushfire', 'Lithgow bushfire', 'Menai bushfire', 'Perth and South-West Region bushfires', 'Linton bushfire', 'Black Christmas bushfires', '2002 NT bushfires', '2003 Canberra bushfires', '2003 Eastern Victorian alpine bushfires', 'Tenterden', '2005 Eyre Peninsula bushfire', 'Jail Break Inn Fire, Junee', '2005 Victorian bushfires', 'Grampians bushfire', 'Pulletop bushfire, Wagga Wagga', 'The Great Divides bushfire', '2006–07 Australian bushfire season', 'Dwellingup bushfire', '2007 Kangaroo Island bushfires', 'Boorabbin National Park', 'Black Saturday bushfires', 'Tasmanian bushfires', 'Warrumbungle bushfire', '2013 New South Wales bushfires', 'Carnarvon bushfire complex', '2015 Sampson Flat bushfires', "2015 O'Sullivan bushfire (Northcliffe – Windy Harbour)", '2015 Lower Hotham bushfire (Boddington)', '2015 Esperance bushfires', 'Perth Hills bushfire complex – Solus Group', '2015 Pinery bushfire', '2016 Murray Road bushfire (Waroona and Harvey)', '2017 New South Wales bushfires', 'Tingha bushfire', '2019–20 Australian bushfire season'], 'state': ['Victoria', 'Victoria', 'Victoria', 'Victoria', 'Victoria', 'New South Wales', 'Victoria', 'South Australia', 'New South Wales', 'New South Wales', 'Western Australia', 'Victoria', 'Victoria', 'New ...

# %%
# Convert dictionary to pandas dataframe
australia_fire_seasons_df = pd.DataFrame.from_dict(australia_fire_seasons_dict,orient='index').transpose()

australia_fire_seasons_df
# Out:
#                              date  \
# 0                 6 February 1851
# 1                 1 February 1898
# 2           February – March 1926
# 3    December 1938 – January 1939
# 4   14 January – 14 February 1944
# ..                            ...
# 63  25 November – 2 December 2015
# 64                   January 2016
# 65          11 – 14 February 2017
# 66            early February 2019
# 67     5 September 2019 – present
#
#                                               name              state  \
# 0                         Black Thursday bushfires           Victoria
# 1                            Red Tuesday bushfires           Victoria
# 2                                   1926 bushfires           Victoria
# 3                           Black Friday bushfires           Victoria
# 4                         1944 Victorian bushfires           Victoria
# ..                                             ...                ...
# 63                            2015 Pinery bushfire    South Australia
# 64  2016 Murray Road bushfire (Waroona and Harvey)  Western Australia
# 65                  2017 New South Wales bushfires    New South Wales
# 66                                 Tingha bushfire    New South Wales
# 67              2019–20 Australian bushfire season         Nationwide
#
#        area_ha  area_acres  fatalities   homes_destroyed
# 0    5,000,000  12,000,000  approx. 12               Nil
# 1      260,000     640,000          12               Nil
# 2      390,000     960,000          60             1,000
# 3    2,000,000   4,900,000          71             3,700
# 4    1,000,000   2,500,000       15–20       approx. 500
# ..         ...         ...         ...               ...
# 63      85,000     210,000           2                91
# 64      69,165     170,910           2               181
# 65      52,000     130,000         Nil                35
# 66      23,419      57,870         Nil                19
# 67  18,626,000  46,030,000       34[j]  approx. 2,600[k]
#
# [68 rows x 7 columns]

# %%
# Drop nas/null values
australia_fire_seasons_df['area_ha'].replace('', np.nan, inplace=True)
australia_fire_seasons_df = australia_fire_seasons_df.dropna(how="any")

# %%
# Verify count/check for null values
australia_fire_seasons_df.count()
# Out:
# date               57
# name               57
# state              57
# area_ha            57
# area_acres         57
# fatalities         57
# homes_destroyed    57
# dtype: int64

# %%
# Check data types
australia_fire_seasons_df.dtypes
# Out:
# date               object
# name               object
# state              object
# area_ha            object
# area_acres         object
# fatalities         object
# homes_destroyed    object
# dtype: object

# %%
# Clean up fatalities column
print(australia_fire_seasons_df["fatalities"].values)

australia_fire_seasons_df["fatalities"].replace({
    "Nil": "0",
    "approx. 12": "12",
    "15–20": "15",
    "5[e]": "5"
}, inplace=True)

print(australia_fire_seasons_df["fatalities"].values)
# Out:
# ['approx. 12' '12' '60' '71' '15–20' '11' '2' 'Nil' 'Nil' '3' '62' 'Nil'
#  'Nil' '6' '4' '2' '2' '5[e]' '75' 'Nil' 'Nil' '5' '3' '4' 'Nil' '3' '2'
#  'Nil' 'Nil' '4' 'Nil' '2' '9' 'Nil' '4' '2' 'Nil' '1' '5' 'Nil' '1' '3'
#  '173' '1' 'Nil' '1' 'Nil' 'Nil' 'Nil' 'Nil' '4' 'Nil' '2' '2' 'Nil' 'Nil'
#  '34[j]']
# ['12' '12' '60' '71' '15' '11' '2' '0' '0' '3' '62' '0' '0' '6' '4' '2'
#  '2' '5' '75' '0' '0' '5' '3' '4' '0' '3' '2' '0' '0' '4' '0' '2' '9' '0'
#  '4' '2' '0' '1' '5' '0' '1' '3' '173' '1' '0' '1' '0' '0' '0' '0' '4' '0'
#  '2' '2' '0' '0' '34[j]']

# %%
# Clean up area_ha column
print(australia_fire_seasons_df["area_ha"].values)

australia_fire_seasons_df["area_ha"].replace({"39,000–160,000": "39,000" }, inplace=True)

print(australia_fire_seasons_df["area_ha"].values)
# Out:
# ['5,000,000' '260,000' '390,000' '2,000,000' '1,000,000' '4,000,000'
#  '39,000–160,000' '1,800,000' '315,000' '251,000' '264,000' '40,000,000'
#  '45,000,000' '117,000,000' '103,000' '54,000' '114,000' '1,000,000'
#  '418,000' '500,000' '516,000' '3,500,000' '50,800' '400,000' '10,500'
#  '400' '23,000' '753,314' '38,000,000' '160,000' '1,300,000' '2,110,000'
#  '77,964' '30,000' '160,000' '184,000' '9,000' '1,048,000' '1,360,000'
#  '12,000' '95,000' '40,000' '450,000' '20,000' '54,000' '100,000'
#  '800,000' '20,000' '98,923' '52,373' '200,000' '10,016' '85,000' '69,165'
#  '52,000' '23,419' '18,626,000']
# ['5,000,000' '260,000' '390,000' '2,000,000' '1,000,000' '4,000,000'
#  '39,000' '1,800,000' '315,000' '251,000' '264,000' '40,000,000'
#  '45,000,000' '117,000,000' '103,000' '54,000' '114,000' '1,000,000'
#  '418,000' '500,000' '516,000' '3,500,000' '50,800' '400,000' '10,500'
#  '400' '23,000' '753,314' '38,000,000' '160,000' '1,300,000' '2,110,000'
#  '77,964' '30,000' '160,000' '184,000' '9,000' '1,048,000' '1,360,000'
#  '12,000' '95,000' '40,000' '450,000' '20,000' '54,000' '100,000'
#  '800,000' '20,000' '98,923' '52,373' '200,000' '10,016' '85,000' '69,165'
#  '52,000' '23,419' '18,626,000']

# %%
# Clean up area_ha column
print(australia_fire_seasons_df["area_acres"].values)

australia_fire_seasons_df["area_acres"].replace({"96,000–395,000": "96,000" }, inplace=True)

print(australia_fire_seasons_df["area_acres"].values)
# Out:
# ['12,000,000' '640,000' '960,000' '4,900,000' '2,500,000' '9,900,000'
#  '96,000–395,000' '4,400,000' '780,000' '620,000' '650,000' '99,000,000'
#  '110,000,000' '290,000,000' '250,000' '130,000' '280,000' '2,500,000'
#  '1,030,000' '1,200,000' '1,280,000' '8,600,000' '126,000' '990,000'
#  '26,000' '990' '57,000' '1,861,480' '94,000,000' '400,000' '3,200,000'
#  '5,200,000' '192,650' '74,000' '400,000' '450,000' '22,000' '2,590,000'
#  '3,400,000' '30,000' '230,000' '99,000' '1,100,000' '49,000' '130,000'
#  '250,000' '2,000,000' '49,000' '244,440' '129,420' '490,000' '24,750'
#  '210,000' '170,910' '130,000' '57,870' '46,030,000']
# ['12,000,000' '640,000' '960,000' '4,900,000' '2,500,000' '9,900,000'
#  '96,000' '4,400,000' '780,000' '620,000' '650,000' '99,000,000'
#  '110,000,000' '290,000,000' '250,000' '130,000' '280,000' '2,500,000'
#  '1,030,000' '1,200,000' '1,280,000' '8,600,000' '126,000' '990,000'
#  '26,000' '990' '57,000' '1,861,480' '94,000,000' '400,000' '3,200,000'
#  '5,200,000' '192,650' '74,000' '400,000' '450,000' '22,000' '2,590,000'
#  '3,400,000' '30,000' '230,000' '99,000' '1,100,000' '49,000' '130,000'
#  '250,000' '2,000,000' '49,000' '244,440' '129,420' '490,000' '24,750'
#  '210,000' '170,910' '130,000' '57,870' '46,030,000']

# %%
# Remove homes_destroyed column
del australia_fire_seasons_df["homes_destroyed"]

# %%
# Drop the last row (2019–20 Australian bushfire season)
australia_fire_seasons_df.drop(australia_fire_seasons_df.tail(1).index,inplace=True)

# %%
# Convert strings to integers
australia_fire_seasons_df['fatalities'] = pd.to_numeric(australia_fire_seasons_df['fatalities'],errors='coerce')

# %%
# Check data types
australia_fire_seasons_df.dtypes
# Out:
# date          object
# name          object
# state         object
# area_ha       object
# area_acres    object
# fatalities     int64
# dtype: object

# %%
# Remove commas from numbers in the area_ha and area_acres columns.
australia_fire_seasons_df['area_ha'].replace(',','', regex=True, inplace=True)
australia_fire_seasons_df['area_acres'].replace(',','', regex=True, inplace=True)

australia_fire_seasons_df.head()
# Out:
#                             date                      name     state  area_ha  \
# 0                6 February 1851  Black Thursday bushfires  Victoria  5000000
# 1                1 February 1898     Red Tuesday bushfires  Victoria   260000
# 2          February – March 1926            1926 bushfires  Victoria   390000
# 3   December 1938 – January 1939    Black Friday bushfires  Victoria  2000000
# 4  14 January – 14 February 1944  1944 Victorian bushfires  Victoria  1000000
#
#   area_acres  fatalities
# 0   12000000          12
# 1     640000          12
# 2     960000          60
# 3    4900000          71
# 4    2500000          15

# %%
# Convert strings to numbers.
australia_fire_seasons_df['area_ha'] = pd.to_numeric(australia_fire_seasons_df['area_ha'],errors='coerce')
australia_fire_seasons_df['area_acres'] = pd.to_numeric(australia_fire_seasons_df['area_acres'],errors='coerce')

australia_fire_seasons_df.dtypes
# Out:
# date          object
# name          object
# state         object
# area_ha        int64
# area_acres     int64
# fatalities     int64
# dtype: object

# %%
# Convert dataframe to dictionary.
australia_fire_seasons_dict = australia_fire_seasons_df.to_dict('range')

australia_fire_seasons_dict
# Out:
# [{'date': '6 February 1851',
#   'name': 'Black Thursday bushfires',
#   'state': 'Victoria',
#   'area_ha': 5000000,
#   'area_acres': 12000000,
#   'fatalities': 12},
#  {'date': '1 February 1898',
#   'name': 'Red Tuesday bushfires',
#   'state': 'Victoria',
#   'area_ha': 260000,
#   'area_acres': 640000,
#   'fatalities': 12},
#  {'date': 'February – March 1926',
#   'name': '1926 bushfires',
#   'state': 'Victoria',
#   'area_ha': 390000,
#   'area_acres': 960000,
#   'fatalities': 60},
#  {'date': 'December 1938 – January 1939',
#   'name': 'Black Friday bushfires',
#   'state': 'Victoria',
#   'area_ha': 2000000,
#   'area_acres': 4900000,
#   'fatalities': 71},
#  {'date': '14 January – 14 February 1944',
#   'name': '1944 Victorian bushfires',
#   'state': 'Victoria',
#   'area_ha': 1000000,
#   'area_acres': 2500000,
#   'fatalities': 15},
#  {'date': 'November 1951 – January 1952',
#   'name': '1951–52 bushfires',
#   'state': 'Victoria',
#   'area_ha': 4000000,
#   'area_acres': 9900000,
#   'fatalities': 11},
#  {'date': '2 January 1955',
#   'name': 'Black Sunday bushfires',
#   'state': 'South Australia',
#   'area_ha': 39000,
#   'area_acres': 96000,
#   'fatalities': 2},
#  {'date': 'January – March 1961',
#   'name': '1961 Western Australian bushfires',
#   'state': 'Western Australia',
#   'area_ha': 1800000,
#   'area_acres': 4400000,
#   'fatalities': 0},
#  {'date': '16 February – 13 March 1965',
#   'name': '1965 Gippsland bushfires',
#   'state': 'Victoria',
#   'area_ha': 315000,
#   'area_acres': 780000,
#   'fatalities': 0},
#  {'date': '5 – 14 March 1965',
#   'name': 'Southern Highlands bushfires',
#   'state': 'New South Wales',
#   'area_ha': 251000,
#   'area_acres': 620000,
#   'fatalities': 3},
#  {'date': '7 February 1967',
#   'name': 'Black Tuesday bushfires',
#   'state': 'Tasmania',
#   'area_ha': 264000,
#   'area_acres': 650000,
#   'fatalities': 62},
#  {'date': '1968 – 69[clarification needed]',
#   'name': '1968-69 Killarney Top Springs bushfires',
#   'state': 'Northern Territory',
#   'area_ha': 40000000,
#   'area_acres': 99000000,
#   'fatalities': 0},
#  {'date': '1969 – 70[clarification needed]',
#   'name': '1969-70 Dry River-Victoria River fire',
#   'state': 'Northern Territory',
#   'area_ha': 45000000,
#   'area_acres': 110000000,
#   'fatalities': 0},
#  {'date': '1974 – 1975 summer fire season(defined as October 1974 to February 1975 in Queensland only)',
#   'name': '1974-75 Australian bushfire season[d]',
#   'state': 'New South WalesNorthern TerritoryQueenslandSouth AustraliaWestern Australia',
#   'area_ha': 117000000,
#   'area_acres': 290000000,
#   'fatalities': 6},
#  {'date': '12 February 1977',
#   'name': 'Western Districts bushfires',
#   'state': 'Victoria',
#   'area_ha': 103000,
#   'area_acres': 250000,
#   'fatalities': 4},
#  {'date': '17 December 1977',
#   'name': 'Blue Mountains Fires 1977',
#   'state': 'New South Wales',
#   'area_ha': 54000,
#   'area_acres': 130000,
#   'fatalities': 2},
#  {'date': '4 April 1978',
#   'name': '1978 Western Australian bushfires',
#   'state': 'Western Australia',
#   'area_ha': 114000,
#   'area_acres': 280000,
#   'fatalities': 2},
#  {'date': '3 November 1980',
#   'name': '1980 Waterfall bushfire',
#   'state': 'New South Wales',
#   'area_ha': 1000000,
#   'area_acres': 2500000,
#   'fatalities': 5},
#  {'date': '16 February 1983',
#   'name': 'Ash Wednesday bushfires',
#   'state': '\nSouth Australia\nVictoria',
#   'area_ha': 418000,
#   'area_acres': 1030000,
#   'fatalities': 75},
#  {'date': '25 December 1984',
#   'name': '1984 Western New South Wales grasslands bushfires',
#   'state': 'New South Wales',
#   'area_ha': 500000,
#   'area_acres': 1200000,
#   'fatalities': 0},
#  {'date': 'Mid-January 1985',
#   'name': '1985 Cobar bushfire',
#   'state': 'New South Wales',
#   'area_ha': 516000,
#   'area_acres': 1280000,
#   'fatalities': 0},
#  {'date': '1984 – 1985 season[clarification needed]',
#   'name': '1984 - 85 New South Wales bushfires',
#   'state': 'New South Wales',
#   'area_ha': 3500000,
#   'area_acres': 8600000,
#   'fatalities': 5},
#  {'date': '14 January 1985',
#   'name': 'Central Victoria bushfires',
#   'state': 'Victoria',
#   'area_ha': 50800,
#   'area_acres': 126000,
#   'fatalities': 3},
#  {'date': '27 December 1993 – 16 January 1994',
#   'name': '1994 Eastern seaboard fires',
#   'state': 'New South Wales',
#   'area_ha': 400000,
#   'area_acres': 990000,
#   'fatalities': 4},
#  {'date': '8 January 1997',
#   'name': 'Wooroloo bushfire',
#   'state': 'Western Australia',
#   'area_ha': 10500,
#   'area_acres': 26000,
#   'fatalities': 0},
#  {'date': '21 January 1997',
#   'name': 'Dandenongs bushfire',
#   'state': 'Victoria',
#   'area_ha': 400,
#   'area_acres': 990,
#   'fatalities': 3},
#  {'date': '2 December 1997',
#   'name': 'Perth and South-West Region bushfires',
#   'state': 'Western Australia',
#   'area_ha': 23000,
#   'area_acres': 57000,
#   'fatalities': 2},
#  {'date': '25 December 2001 – 7 January 2002',
#   'name': 'Black Christmas bushfires',
#   'state': 'New South Wales',
#   'area_ha': 753314,
#   'area_acres': 1861480,
#   'fatalities': 0},
#  {'date': 'August – November 2002',
#   'name': '2002 NT bushfires',
#   'state': 'Northern Territory',
#   'area_ha': 38000000,
#   'area_acres': 94000000,
#   'fatalities': 0},
#  {'date': '18 – 22 January 2003',
#   'name': '2003 Canberra bushfires',
#   'state': 'Australian Capital Territory',
#   'area_ha': 160000,
#   'area_acres': 400000,
#   'fatalities': 4},
#  {'date': '8 January – 8 March 2003',
#   'name': '2003 Eastern Victorian alpine bushfires',
#   'state': 'Victoria',
#   'area_ha': 1300000,
#   'area_acres': 3200000,
#   'fatalities': 0},
#  {'date': 'December 2003',
#   'name': 'Tenterden',
#   'state': 'Western Australia',
#   'area_ha': 2110000,
#   'area_acres': 5200000,
#   'fatalities': 2},
#  {'date': '10 – 12 January 2005',
#   'name': '2005 Eyre Peninsula bushfire',
#   'state': 'South Australia',
#   'area_ha': 77964,
#   'area_acres': 192650,
#   'fatalities': 9},
#  {'date': 'New Years Day 2006',
#   'name': 'Jail Break Inn Fire, Junee',
#   'state': 'New South Wales',
#   'area_ha': 30000,
#   'area_acres': 74000,
#   'fatalities': 0},
#  {'date': 'December 2005 – January 2006',
#   'name': '2005 Victorian bushfires',
#   'state': 'Victoria',
#   'area_ha': 160000,
#   'area_acres': 400000,
#   'fatalities': 4},
#  {'date': 'January 2006',
#   'name': 'Grampians bushfire',
#   'state': 'Victoria',
#   'area_ha': 184000,
#   'area_acres': 450000,
#   'fatalities': 2},
#  {'date': '6 February 2006',
#   'name': 'Pulletop bushfire, Wagga Wagga',
#   'state': 'New South Wales',
#   'area_ha': 9000,
#   'area_acres': 22000,
#   'fatalities': 0},
#  {'date': '1 December 2006 –  March 2007',
#   'name': 'The Great Divides bushfire',
#   'state': 'Victoria',
#   'area_ha': 1048000,
#   'area_acres': 2590000,
#   'fatalities': 1},
#  {'date': 'September 2006 – January 2007',
#   'name': '2006–07 Australian bushfire season',
#   'state': '\nNew South Wales\nSouth Australia\nTasmania\nVictoria\nWestern Australia',
#   'area_ha': 1360000,
#   'area_acres': 3400000,
#   'fatalities': 5},
#  {'date': '4 February 2007',
#   'name': 'Dwellingup bushfire',
#   'state': 'Western Australia',
#   'area_ha': 12000,
#   'area_acres': 30000,
#   'fatalities': 0},
#  {'date': '6 – 14 December 2007',
#   'name': '2007 Kangaroo Island bushfires',
#   'state': 'South Australia',
#   'area_ha': 95000,
#   'area_acres': 230000,
#   'fatalities': 1},
#  {'date': '30 December 2007',
#   'name': 'Boorabbin National Park',
#   'state': 'Western Australia',
#   'area_ha': 40000,
#   'area_acres': 99000,
#   'fatalities': 3},
#  {'date': '7 February – 14 March 2009',
#   'name': 'Black Saturday bushfires',
#   'state': 'Victoria',
#   'area_ha': 450000,
#   'area_acres': 1100000,
#   'fatalities': 173},
#  {'date': '4 January 2013',
#   'name': 'Tasmanian bushfires',
#   'state': 'Tasmania',
#   'area_ha': 20000,
#   'area_acres': 49000,
#   'fatalities': 1},
#  {'date': '18 January 2013',
#   'name': 'Warrumbungle bushfire',
#   'state': 'New South Wales',
#   'area_ha': 54000,
#   'area_acres': 130000,
#   'fatalities': 0},
#  {'date': '17 – 28 October 2013',
#   'name': '2013 New South Wales bushfires',
#   'state': 'New South Wales',
#   'area_ha': 100000,
#   'area_acres': 250000,
#   'fatalities': 1},
#  {'date': '27 December 2011 – 3 February 2012',
#   'name': 'Carnarvon bushfire complex',
#   'state': 'Western Australia',
#   'area_ha': 800000,
#   'area_acres': 2000000,
#   'fatalities': 0},
#  {'date': '2 – 9 January 2015',
#   'name': '2015 Sampson Flat bushfires',
#   'state': 'South Australia',
#   'area_ha': 20000,
#   'area_acres': 49000,
#   'fatalities': 0},
#  {'date': '29 January – 20 February 2015',
#   'name': "2015 O'Sullivan bushfire (Northcliffe – Windy Harbour)",
#   'state': 'Western Australia',
#   'area_ha': 98923,
#   'area_acres': 244440,
#   'fatalities': 0},
#  {'date': 'January 2015',
#   'name': '2015 Lower Hotham bushfire (Boddington)',
#   'state': 'Western Australia',
#   'area_ha': 52373,
#   'area_acres': 129420,
#   'fatalities': 0},
#  {'date': 'October – November 2015',
#   'name': '2015 Esperance bushfires',
#   'state': 'Western Australia',
#   'area_ha': 200000,
#   'area_acres': 490000,
#   'fatalities': 4},
#  {'date': '15 – 24 November 2015',
#   'name': 'Perth Hills bushfire complex – Solus Group',
#   'state': 'Western Australia',
#   'area_ha': 10016,
#   'area_acres': 24750,
#   'fatalities': 0},
#  {'date': '25 November – 2 December 2015',
#   'name': '2015 Pinery bushfire',
#   'state': 'South Australia',
#   'area_ha': 85000,
#   'area_acres': 210000,
#   'fatalities': 2},
#  {'date': 'January 2016',
#   'name': '2016 Murray Road bushfire (Waroona and Harvey)',
#   'state': 'Western Australia',
#   'area_ha': 69165,
#   'area_acres': 170910,
#   'fatalities': 2},
#  {'date': '11 – 14 February 2017',
#   'name': '2017 New South Wales bushfires',
#   'state': 'New South Wales',
#   'area_ha': 52000,
#   'area_acres': 130000,
#   'fatalities': 0},
#  {'date': 'early February 2019',
#   'name': 'Tingha bushfire',
#   'state': 'New South Wales',
#   'area_ha': 23419,
#   'area_acres': 57870,
#   'fatalities': 0}]
